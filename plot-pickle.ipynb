# %%
from ozzy_torch_utils.plot import *
import pickle
import os

# %%
pickle_pathname = "/uolstore/home/student_lnxhome01/sc22olj/Compsci/year3/individual-project-COMP3931/individual-project-sc22olj/runs/run_12-03-2025_23-31-31/run_12-03-2025_23-31-31_metrics.pkl"

with open(pickle_pathname, 'rb') as file:
    
    metrics = pickle.load(file)
    
plot(metrics, '', save_params = False, save_metrics = False, save_png = False, ylim = (0,4))
# Out:
# 146
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 7
#       3 with open(pickle_pathname, 'rb') as file:
#       5     metrics = pickle.load(file)
# ----> 7 plot(metrics, '', save_params = False, save_metrics = False, save_png = False, ylim = (0,4))
#
# File /uolstore/home/student_lnxhome01/sc22olj/Compsci/year3/individual-project-COMP3931/individual-project-sc22olj/ozzy_torch_utils/plot.py:116, in plot(metrics, model_parameters, save_params, save_metrics, save_png, ylim)
#     114 info.append("Parameters:")
#     115 info.append("\n")
# --> 116 info.append(f"Model name: {model_parameters.model.__class__.__module__}.{model_parameters.model.__class__.__name__}")
#     117 info.append(f"Model optimiser: {model_parameters.optimiser}")
# ...
